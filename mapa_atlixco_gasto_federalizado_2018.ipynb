# %% [markdown]
# <a href="https://colab.research.google.com/github/josantgl/Inteligencia-comunitaria/blob/master/mapa_atlixco_gasto_federalizado_2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gasto federalizado Atlixco, Puebla 2018

# %%
import pandas

# %%
nombre_de_archivo = '/federalizadoatlixco2018lonlat.xls'
dataframe = pandas.read_excel(nombre_de_archivo)

# %%
dataframe.head
# Out:
# <bound method NDFrame.head of      CICLO  TRIMESTRE  ...        LON        LAT
# 0     2018          3  ... -98.476972  18.944751
# 1     2018          3  ... -98.437777  18.908888
# 2     2018          3  ... -97.952715  19.104940
# 3     2018          3  ... -97.952715  19.104940
# 4     2018          3  ... -97.952715  19.104940
# ..     ...        ...  ...        ...        ...
# 135   2018          3  ... -98.437777  18.908888
# 136   2018          3  ... -98.437777  18.908888
# 137   2018          3  ... -98.437777  18.908888
# 138   2018          3  ... -98.452201  18.887645
# 139   2018          3  ... -98.437777  18.908888
#
# [140 rows x 37 columns]>

# %%
cabeceras = list(dataframe)
cabeceras
# Out:
# ['CICLO',
#  'TRIMESTRE',
#  'FOLIO',
#  'CATEGORIA',
#  'MONTO_GLOBAL_APROBADO',
#  'FUENTES_FINANCIAMIENTO',
#  'NOMBRE',
#  'ID_ENTIDAD_RESPONSABLE',
#  'ENTIDAD_RESPONSABLE',
#  'ID_MUNICIPIO_RESPONSABLE',
#  'MUNICIPIO_RESPONSABLE',
#  'TIPO_PROGRAMA_PROYECTO',
#  'CLASIFICACION',
#  'SUBCLASIFICACION',
#  'INSTITUCION_EJECUTORA',
#  'NUMERO_PROYECTO',
#  'POBLACION_BENEFICIADA',
#  'MUJERES',
#  'HOMBRES',
#  'BENEFICIARIOS',
#  'METAS',
#  'TIPO_GEOREFERENCIA',
#  'GEOREFERENCIAS',
#  'FECHA_INICIO',
#  'FECHA_TERMINO',
#  'RECAUDADO',
#  'COMPROMETIDO',
#  'DEVENGADO',
#  'EJERCIDO',
#  'PAGADO',
#  'CONTRATOS',
#  'AVANCES_FISICOS',
#  'CARPETA_FOTOS',
#  'ESTATUS',
#  'FLUJO',
#  'LON',
#  'LAT']

# %%
beneficiarios = dataframe [['BENEFICIARIOS']]
beneficiarios
# Out:
#      BENEFICIARIOS
# 0               52
# 1            86680
# 2               50
# 3               50
# 4             1130
# ..             ...
# 135              0
# 136              0
# 137            500
# 138            500
# 139            500
#
# [140 rows x 1 columns]

# %%
monto = dataframe [['PAGADO']]
monto
# Out:
#          PAGADO
# 0           NaN
# 1     226239.65
# 2    1148326.68
# 3    1827665.75
# 4    1427718.91
# ..          ...
# 135   215991.79
# 136   289698.98
# 137   945777.70
# 138   402280.40
# 139   402248.40
#
# [140 rows x 1 columns]

# %%
poblacion.values
monto.values
# Out:
# array([[       nan],
#        [ 226239.65],
#        [1148326.68],
#        [1827665.75],
#        [1427718.91],
#        [ 677196.04],
#        [1182545.69],
#        [ 562546.79],
#        [1996987.44],
#        [ 726938.93],
#        [2163595.74],
#        [ 689592.12],
#        [ 321533.37],
#        [1582981.53],
#        [1109200.1 ],
#        [1447342.16],
#        [ 614463.72],
#        [1264733.2 ],
#        [1447327.32],
#        [3519526.63],
#        [ 967107.72],
#        [1309983.94],
#        [ 612609.05],
#        [ 745104.  ],
#        [1084751.64],
#        [1551188.56],
#        [2000000.  ],
#        [1200000.  ],
#        [ 387498.85],
#        [1198800.  ],
#        [1995102.9 ],
#        [2190207.6 ],
#        [3996000.  ],
#        [ 971037.99],
#        [ 165618.08],
#        [ 498648.  ],
#        [1850374.  ],
#        [ 666134.64],
#        [ 370074.8 ],
#        [ 370074.8 ],
#        [1319940.  ],
#        [      0.  ],
#        [      0.  ],
# ...

# %%
monto.values
# Out:
# array([[       nan],
#        [ 226239.65],
#        [1148326.68],
#        [1827665.75],
#        [1427718.91],
#        [ 677196.04],
#        [1182545.69],
#        [ 562546.79],
#        [1996987.44],
#        [ 726938.93],
#        [2163595.74],
#        [ 689592.12],
#        [ 321533.37],
#        [1582981.53],
#        [1109200.1 ],
#        [1447342.16],
#        [ 614463.72],
#        [1264733.2 ],
#        [1447327.32],
#        [3519526.63],
#        [ 967107.72],
#        [1309983.94],
#        [ 612609.05],
#        [ 745104.  ],
#        [1084751.64],
#        [1551188.56],
#        [2000000.  ],
#        [1200000.  ],
#        [ 387498.85],
#        [1198800.  ],
#        [1995102.9 ],
#        [2190207.6 ],
#        [3996000.  ],
#        [ 971037.99],
#        [ 165618.08],
#        [ 498648.  ],
#        [1850374.  ],
#        [ 666134.64],
#        [ 370074.8 ],
#        [ 370074.8 ],
#        [1319940.  ],
#        [      0.  ],
#        [      0.  ],
# ...

# %%
dataframe [dataframe['PAGADO']>200000]
# Out:
#      CICLO  TRIMESTRE  ...        LON        LAT
# 1     2018          3  ... -98.437777  18.908888
# 2     2018          3  ... -97.952715  19.104940
# 3     2018          3  ... -97.952715  19.104940
# 4     2018          3  ... -97.952715  19.104940
# 5     2018          3  ... -97.952715  19.104940
# ..     ...        ...  ...        ...        ...
# 135   2018          3  ... -98.437777  18.908888
# 136   2018          3  ... -98.437777  18.908888
# 137   2018          3  ... -98.437777  18.908888
# 138   2018          3  ... -98.452201  18.887645
# 139   2018          3  ... -98.437777  18.908888
#
# [90 rows x 37 columns]

# %%
dataframe [dataframe['BENEFICIARIOS']>50]
# Out:
#      CICLO  TRIMESTRE  ...        LON        LAT
# 0     2018          3  ... -98.476972  18.944751
# 1     2018          3  ... -98.437777  18.908888
# 4     2018          3  ... -97.952715  19.104940
# 7     2018          3  ... -97.952715  19.104940
# 8     2018          3  ... -97.952715  19.104940
# ..     ...        ...  ...        ...        ...
# 124   2018          3  ... -98.358252  18.921316
# 126   2018          3  ... -98.404722  18.899166
# 137   2018          3  ... -98.437777  18.908888
# 138   2018          3  ... -98.452201  18.887645
# 139   2018          3  ... -98.437777  18.908888
#
# [85 rows x 37 columns]

# %%
beneficiarios.values
# Out:
# array([[    52],
#        [ 86680],
#        [    50],
#        [    50],
#        [  1130],
#        [    50],
#        [    43],
#        [   100],
#        [  1130],
#        [     0],
#        [   150],
#        [     0],
#        [     0],
#        [   150],
#        [     0],
#        [   100],
#        [     0],
#        [     0],
#        [     0],
#        [ 18025],
#        [   196],
#        [   248],
#        [     0],
#        [     0],
#        [     0],
#        [     0],
#        [ 86690],
#        [     0],
#        [   825],
#        [   350],
#        [   233],
#        [   233],
#        [  5000],
#        [    24],
#        [ 21027],
#        [ 54000],
#        [   215],
#        [    77],
#        [    43],
#        [    43],
#        [   615],
#        [   700],
#        [   253],
#        [   571],
#        [   350],
#        [   425],
#        [   450],
#        [   250],
#        [   350],
#        [   450],
#        [   350],
#        [   350],
# ...

# %%
dataframe[dataframe ['CLASIFICACION']== 'Seguridad']
# Out:
#     CICLO  TRIMESTRE              FOLIO  ...             FLUJO        LON        LAT
# 92   2018          3  PUE18180101076285  ...  Validado avances -98.437777  18.908888
# 93   2018          3  PUE18180101076291  ...  Validado avances -98.437777  18.908888
# 94   2018          3  PUE18180101076299  ...  Validado avances -98.437777  18.908888
#
# [3 rows x 37 columns]

# %%
dataframe.count()
# Out:
# CICLO                       140
# TRIMESTRE                   140
# FOLIO                       140
# CATEGORIA                   140
# MONTO_GLOBAL_APROBADO       140
# FUENTES_FINANCIAMIENTO      140
# NOMBRE                      140
# ID_ENTIDAD_RESPONSABLE      140
# ENTIDAD_RESPONSABLE         140
# ID_MUNICIPIO_RESPONSABLE    140
# MUNICIPIO_RESPONSABLE       140
# TIPO_PROGRAMA_PROYECTO      129
# CLASIFICACION               140
# SUBCLASIFICACION            140
# INSTITUCION_EJECUTORA       140
# NUMERO_PROYECTO             137
# POBLACION_BENEFICIADA       140
# MUJERES                     140
# HOMBRES                     140
# BENEFICIARIOS               140
# METAS                       140
# TIPO_GEOREFERENCIA          140
# GEOREFERENCIAS              140
# FECHA_INICIO                140
# FECHA_TERMINO               101
# RECAUDADO                   137
# COMPROMETIDO                137
# DEVENGADO                   137
# EJERCIDO                    137
# ...

# %%
dataframe.describe()
# Out:
#         CICLO  TRIMESTRE  ...         LON         LAT
# count   140.0      140.0  ...  140.000000  140.000000
# mean   2018.0        3.0  ...  -98.372415   18.926637
# std       0.0        0.0  ...    0.176027    0.091823
# min    2018.0        3.0  ...  -98.556532   18.202301
# 25%    2018.0        3.0  ...  -98.442624   18.905231
# 50%    2018.0        3.0  ...  -98.435539   18.908888
# 75%    2018.0        3.0  ...  -98.407136   18.921469
# max    2018.0        3.0  ...  -97.662870   19.104940
#
# [8 rows x 16 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set (style = 'darkgrid')

# %%
plt.figure (figsize= (15,20))
sns.barplot(x='BENEFICIARIOS', y='NOMBRE', data=dataframe,
label= "Poblacion beneficiada", color="b")

# %%
lat_long =  (dataframe[['LAT','LON']]).values
lat_long
# Out:
# array([[ 18.94475073, -98.47697241],
#        [ 18.908888  , -98.437777  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 19.10494   , -97.952715  ],
#        [ 18.202301  , -98.048606  ],
#        [ 18.793291  , -97.66287   ],
#        [ 18.864444  , -98.4225    ],
#        [ 18.946863  , -98.390235  ],
#        [ 18.908888  , -98.437777  ],
#        [ 18.908888  , -98.437777  ],
# ...

# %%
etiquetas = (dataframe[['NOMBRE']]).values
etiquetas
# Out:
# array([['Contruccion De Drenaje En Calle Ocho Norte Entre Cuatro Oriente Y Prolongación De La Tres Oriente - 111415'],
#        ['Construc Del Colector Pluvial Del Boulevard Niños Heroes Y Paseo De Los Fresnos, Con Inicio En Calle 20 De Nov. Y Descarga En Barranca El Cuexcomate En La Loc. De Atlixco Del Municipio De Atlixco'],
#        ['Construccion De Techado Para La Plaza Civica De La Escuela Primaria Rural Federal ""Otilio Montaño""'],
#        ['Adoquinamiento De La Calle Prolongacion Independencia Y Calle Prolongacion 3 Sur'],
#        ['Adoquinamiento Calle Ignacio Allende Iniciando En Calle Miguel Hidalgo Y Concluyendo  Hasta Calle Morelos, Emiliano Zapata Los Molinos'],
#        ['Techado En La Escuela Primaria Federal Felipe Carrillo Puerto C.C.T. 21dpr2236j'],
#        ['Construcción De Explanada Y Pavimentación Con Concreto Hidráulico Del Acceso A La Secundaria Técnica Josefa Ortiz De Domínguez Con Clave 21dst0149m, En La Localidad El Encanto Del Cerril, Atlixco.'],
# ...

# %%
monto = (dataframe[['PAGADO']]).values
monto
# Out:
# array([[       nan],
#        [ 226239.65],
#        [1148326.68],
#        [1827665.75],
#        [1427718.91],
#        [ 677196.04],
#        [1182545.69],
#        [ 562546.79],
#        [1996987.44],
#        [ 726938.93],
#        [2163595.74],
#        [ 689592.12],
#        [ 321533.37],
#        [1582981.53],
#        [1109200.1 ],
#        [1447342.16],
#        [ 614463.72],
#        [1264733.2 ],
#        [1447327.32],
#        [3519526.63],
#        [ 967107.72],
#        [1309983.94],
#        [ 612609.05],
#        [ 745104.  ],
#        [1084751.64],
#        [1551188.56],
#        [2000000.  ],
#        [1200000.  ],
#        [ 387498.85],
#        [1198800.  ],
#        [1995102.9 ],
#        [2190207.6 ],
#        [3996000.  ],
#        [ 971037.99],
#        [ 165618.08],
#        [ 498648.  ],
#        [1850374.  ],
#        [ 666134.64],
#        [ 370074.8 ],
#        [ 370074.8 ],
#        [1319940.  ],
#        [      0.  ],
#        [      0.  ],
# ...

# %%
beneficiarios = (dataframe[['BENEFICIARIOS']]).values
beneficiarios
# Out:
# array([[    52],
#        [ 86680],
#        [    50],
#        [    50],
#        [  1130],
#        [    50],
#        [    43],
#        [   100],
#        [  1130],
#        [     0],
#        [   150],
#        [     0],
#        [     0],
#        [   150],
#        [     0],
#        [   100],
#        [     0],
#        [     0],
#        [     0],
#        [ 18025],
#        [   196],
#        [   248],
#        [     0],
#        [     0],
#        [     0],
#        [     0],
#        [ 86690],
#        [     0],
#        [   825],
#        [   350],
#        [   233],
#        [   233],
#        [  5000],
#        [    24],
#        [ 21027],
#        [ 54000],
#        [   215],
#        [    77],
#        [    43],
#        [    43],
#        [   615],
#        [   700],
#        [   253],
#        [   571],
#        [   350],
#        [   425],
#        [   450],
#        [   250],
#        [   350],
#        [   450],
#        [   350],
#        [   350],
# ...

# %%
import folium

# %%
mapa_atlixco = folium.Map (
    location=[18.912500, -98.427778],
    zoom_start=13
)

# %%
mapa_atlixco
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
for i in range(len(etiquetas)):
  folium.Marker(lat_long[i],
                popup=f"Poblacion beneficiada: {beneficiarios[i][0]} personas", 
                
                tooltip=etiquetas[i][0],
                icon=folium.Icon(color='gray', prefix='fa', icon='check')
  ).add_to(mapa_atlixco)

# %%
#@title Default title text
mapa_atlixco
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
ra
